# %% [markdown]
# # Multi-Layer Perceptron on MNIST

# %% [markdown]
# ## [ CONTENTS ]
#
# 1. About the dataset<br>
# 2. Objective<br>
# 3. Loading Libraries & Data <br>
# 4. Data Preprocessing <br>
# 5. Experiments<br>
# 6. Summery

# %% [markdown]
# ## 1. About the dataset
# The MNIST database of handwritten digits, available from this page, has a training set of 60,000 examples, and a test set of 10,000 examples. It is a subset of a larger set available from NIST. The digits have been size-normalized and centered in a fixed-size image.<br>
# <br>
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel, with higher numbers meaning darker. This pixel-value is an integer between 0 and 255, inclusive.

# %% [markdown]
# ## 2. Objective:
# The objective here is to classify handwritten digits using Multi-Layer Perceptron. Apart from that, here I will conduct various experiments with number of layers, number of hidden units, types of optimizers, different regularization and their effect on classification.
# <br>
# (**Note: Here I'm using Keras for the simplicity and ease of implementation which uses tensorflow at it's backend.**)

# %% [markdown]
# ## 3. Loading Libraries & Data

# %%
#importing libraries
import warnings
warnings.filterwarnings('ignore')
from keras.datasets import mnist
from keras import models 
from keras import layers
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
#loading the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
plt.imshow(train_images[5], cmap = 'binary')

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
plt.imshow(test_images[5], cmap = 'binary')

# %% [markdown]
# ## 4. Data Preprocessing

# %%
# normalizing train and test data 
# It helps in quicker convergence 
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
#converting the labels to categorial variable 
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %% [markdown]
# ## 5. Experiments

# %% [markdown]
# ### 5.1  Hidden Layer

# %%
#simple multilayer perceptrons of varying hidden layers
def mlp_builder(num_layer):
    
    #MLP with 2 hidden layers
    if num_layer == 2:
        
        network = models.Sequential()
        network.add(layers.Dense(512, activation = 'relu', input_shape = (28 * 28,)))
        network.add(layers.Dense(128, activation = 'relu'))
        network.add(layers.Dense(10, activation = 'softmax'))
        
        network.compile(optimizer = 'adam',
                        loss = 'categorical_crossentropy',
                        metrics = ['accuracy'])
        
        history = network.fit(train_images, train_labels,
                              validation_split = 0.33, epochs = 20,
                              batch_size = 128, verbose = 0)
        train_cv_plot(history)
    
    #MLP with 3 hidden layers
    elif num_layer == 3:
        
        network = models.Sequential()
        network.add(layers.Dense(512, activation = 'relu', input_shape = (28 * 28,)))
        network.add(layers.Dense(256, activation = 'relu'))
        network.add(layers.Dense(128, activation = 'relu'))
        network.add(layers.Dense(10, activation = 'softmax'))
        
        network.compile(optimizer = 'adam',
                        loss = 'categorical_crossentropy',
                        metrics = ['accuracy'])
        
        history = network.fit(train_images, train_labels,
                              validation_split = 0.33, epochs = 20,
                              batch_size = 128, verbose = 0)
        train_cv_plot(history)
    #MLP with 5 hidden layers
    else :
        
        network = models.Sequential()
        network.add(layers.Dense(512, activation = 'relu', input_shape = (28 * 28,)))
        network.add(layers.Dense(256, activation = 'relu'))
        network.add(layers.Dense(128, activation = 'relu'))
        network.add(layers.Dense(64, activation = 'relu'))
        network.add(layers.Dense(32, activation = 'relu'))
        network.add(layers.Dense(10, activation = 'softmax'))
        
        network.compile(optimizer = 'adam',
                        loss = 'categorical_crossentropy',
                        metrics = ['accuracy'])
        
        history = network.fit(train_images, train_labels,
                              validation_split = 0.33, epochs = 20,
                              batch_size = 128, verbose = 0)
        train_cv_plot(history)

# %%
#plot the train and cv error and accuracy curve
def train_cv_plot(history):
    
    sns.set()
    # train-cv plot for accuracy
    plt.figure(figsize = (8, 5))
    plt.plot(np.arange(1, 21, step = 1), history.history['acc'], color = 'b')
    plt.plot(np.arange(1, 21, step = 1), history.history['val_acc'], color = 'r')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'CV'])
    plt.show()
        
    # train-cv plot for loss
    plt.figure(figsize = (8, 5))
    plt.plot(np.arange(1, 21, step = 1), history.history['loss'], color = 'b')
    plt.plot(np.arange(1, 21, step = 1), history.history['val_loss'], color = 'r')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'CV'])
    plt.show()

# %% [markdown]
# ### 5.2 Hidden Units

# %%
#simple multilayer perceptrons of varying hidden units
def var_hidden_units():
    
    err_stack = np.arange(1, 21)
    for hidden_units in [32, 64, 128, 256, 512]:
        network = models.Sequential()
        network.add(layers.Dense(hidden_units, activation = 'relu', input_shape = (28 * 28,)))
        network.add(layers.Dense(10, activation = 'softmax'))
    
        network.compile(optimizer = 'adam',
                        loss = 'categorical_crossentropy',
                        metrics = ['accuracy'])
    
        history = network.fit(train_images, train_labels, batch_size = 128, 
                              verbose = 0, epochs = 20)
        err_stack = np.vstack([err_stack, history.history['loss']])
        
    hidunits_err_plot(err_stack[1:, :])

# %%
#plot the train and cv error curve
def hidunits_err_plot(err_stack):
    
    sns.set()
    plt.figure(figsize = (8, 5))
    plt.plot(np.arange(1, 21, step = 1), err_stack[0, :], color = 'r')
    plt.plot(np.arange(1, 21, step = 1), err_stack[1, :], color = 'g')
    plt.plot(np.arange(1, 21, step = 1), err_stack[2, :], color = 'b')
    plt.plot(np.arange(1, 21, step = 1), err_stack[3, :], color = 'c')
    plt.plot(np.arange(1, 21, step = 1), err_stack[4, :], color = 'm')
    
    plt.title('Hidden Units Comparision')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['32-units', '64-units', '128-units', '256-units', '512-units'])
    
    plt.show()

# %% [markdown]
# ### 5.3 Various Optimizers

# %%
#simple multilayer perceptrons of varying optimizers
def var_optimizer():
    
    err_stack = np.arange(1, 21)
    optimizer_list = ['sgd', 'rmsprop', 'adam']
    network = models.Sequential()
    network.add(layers.Dense(8, activation = 'sigmoid', input_shape = (28 * 28,)))
    network.add(layers.Dense(10, activation = 'softmax'))
    
    for optmzr in optimizer_list:
        network.compile(optimizer = optmzr,
                        loss = 'categorical_crossentropy',
                        metrics = ['accuracy'])
        history = network.fit(train_images, train_labels, batch_size = 128, 
                              epochs = 20, verbose = 0)
        err_stack = np.vstack([err_stack, history.history['loss']])
    
    err_plot(err_stack[1:, :])

# %%
#plot the train and cv error curve
def err_plot(err_stack):
    
    sns.set()
    plt.figure(figsize = (8, 5))
    plt.plot(np.arange(1, 21, step = 1), err_stack[0, :], color = 'r')
    plt.plot(np.arange(1, 21, step = 1), err_stack[1, :], color = 'b')
    plt.plot(np.arange(1, 21, step = 1), err_stack[2, :], color = 'g')
    
    plt.title('Optimizers Comparision')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam'])
    
    plt.show()

# %% [markdown]
# ### 5.4 Various Regularization

# %%
#simple multilayer perceptrons of varying regularizers
from keras import regularizers

def var_regularizers():
    
    penalty = ['l1', 'l2', 'l1_l2', 'dropout']
    err_stack = np.arange(1, 21)
    
    for penalize in penalty:
        
        if penalize == 'l1':
            network = models.Sequential()
            network.add(layers.Dense(256, activation = 'relu',
                                     kernel_regularizer = regularizers.l1(0.0001), 
                                     input_shape = (28 * 28,)))
            network.add(layers.Dense(512, activation = 'relu',
                                     kernel_regularizer = regularizers.l1(0.0001)))
            network.add(layers.Dense(128, activation = 'relu',
                                     kernel_regularizer = regularizers.l1(0.0001)))
            network.add(layers.Dense(64, activation = 'relu',
                                     kernel_regularizer = regularizers.l1(0.0001)))
            network.add(layers.Dense(10, activation = 'softmax',
                                     kernel_regularizer = regularizers.l1(0.0001)))
    
            network.compile(optimizer = 'adam',
                            loss = 'categorical_crossentropy',
                            metrics = ['accuracy'])
                            
            history = network.fit(train_images, train_labels, batch_size = 128, 
                              epochs = 20, verbose = 0)
            err_stack = np.vstack([err_stack, history.history['loss']])
                            
        elif penalize == 'l2': 
            network = models.Sequential()
            network.add(layers.Dense(256, activation = 'relu',
                                     kernel_regularizer = regularizers.l2(0.0001), 
                                     input_shape = (28 * 28,)))
            network.add(layers.Dense(512, activation = 'relu',
                                     kernel_regularizer = regularizers.l2(0.0001)))
            network.add(layers.Dense(128, activation = 'relu',
                                     kernel_regularizer = regularizers.l2(0.0001)))
            network.add(layers.Dense(64, activation = 'relu',
                                     kernel_regularizer = regularizers.l2(0.0001)))
            network.add(layers.Dense(10, activation = 'softmax',
                                     kernel_regularizer = regularizers.l2(0.0001)))
    
            network.compile(optimizer = 'adam',
                            loss = 'categorical_crossentropy',
                            metrics = ['accuracy'])
                            
            history = network.fit(train_images, train_labels, batch_size = 128, 
                              epochs = 20, verbose = 0)
            err_stack = np.vstack([err_stack, history.history['loss']])
                            
        elif penalize == 'l1_l2': 
            network = models.Sequential()
            network.add(layers.Dense(256, activation = 'relu',
                                     kernel_regularizer = regularizers.l1_l2(l1=0.0001, l2=0.0001), 
                                     input_shape = (28 * 28,)))
            network.add(layers.Dense(512, activation = 'relu',
                                     kernel_regularizer = regularizers.l1_l2(l1=0.0001, l2=0.0001)))
            network.add(layers.Dense(128, activation = 'relu',
                                     kernel_regularizer = regularizers.l1_l2(l1=0.0001, l2=0.0001)))
            network.add(layers.Dense(64, activation = 'relu',
                                     kernel_regularizer = regularizers.l1_l2(l1=0.0001, l2=0.0001)))
            network.add(layers.Dense(10, activation = 'softmax',
                                     kernel_regularizer = regularizers.l1_l2(l1=0.0001, l2=0.0001)))
    
            network.compile(optimizer = 'adam',
                            loss = 'categorical_crossentropy',
                            metrics = ['accuracy'])
                            
            history = network.fit(train_images, train_labels, batch_size = 128, 
                              epochs = 20, verbose = 0)
            err_stack = np.vstack([err_stack, history.history['loss']])
                            
        else:
            network = models.Sequential()
            network.add(layers.Dense(256, activation = 'relu', input_shape = (28 * 28,)))
            network.add(layers.Dropout(0.5))
            network.add(layers.Dense(512, activation = 'relu'))
            network.add(layers.Dropout(0.5))
            network.add(layers.Dense(128, activation = 'relu'))
            network.add(layers.Dropout(0.5))
            network.add(layers.Dense(64, activation = 'relu'))
            network.add(layers.Dropout(0.5))
            network.add(layers.Dense(10, activation = 'softmax'))
    
            network.compile(optimizer = 'adam',
                            loss = 'categorical_crossentropy',
                            metrics = ['accuracy'])
                            
            history = network.fit(train_images, train_labels, batch_size = 128, 
                              epochs = 20, verbose = 0)
            err_stack = np.vstack([err_stack, history.history['loss']])
    
    err_plot_reglzr(err_stack[1:, :])

# %%
#plot the train and cv error curve
def err_plot_reglzr(err_stack):
    
    sns.set()
    plt.figure(figsize = (8, 5))
    plt.plot(np.arange(1, 21, step = 1), err_stack[0, :], color = 'r')
    plt.plot(np.arange(1, 21, step = 1), err_stack[1, :], color = 'b')
    plt.plot(np.arange(1, 21, step = 1), err_stack[2, :], color = 'g')
    plt.plot(np.arange(1, 21, step = 1), err_stack[3, :], color = 'm')
    
    plt.title('Regularizers Comparision')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['L1', 'L2', 'L1_L2', 'Dropout'])
    
    plt.show()

# %% [markdown]
# ### 5.5 Final Model

# %%
# final simple multilayer perceptron model
def final_mlp():
    
    network = models.Sequential()
    network.add(layers.Dense(256, activation = 'relu', input_shape = (28 * 28,),
                            kernel_regularizer = regularizers.l2(0.0001)))
    network.add(layers.Dense(512, activation = 'relu',
                            kernel_regularizer = regularizers.l2(0.0001)))
    network.add(layers.Dense(128, activation = 'relu'))
    network.add(layers.Dropout(0.5))
    network.add(layers.Dense(64, activation = 'relu'))
    network.add(layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001))
    network.add(layers.Dense(10, activation = 'softmax'))
    
    network.compile(optimizer = 'adam',
                    loss = 'categorical_crossentropy',
                    metrics = ['accuracy'])
                            
    network.fit(train_images, train_labels, batch_size = 128, 
                    epochs = 2, verbose = 0)
    result = network.evaluate(test_images, test_labels)
    print(network.summary())
    print('Final Model Accuracy on Test data is: {}%'.format(result[1] * 100))

# %% [markdown]
# ## [A] Varying Hidden Layers

# %%
#2-hidden layered MLP
mlp_builder(2)

# %%
#3-hidden layered MLP
mlp_builder(3)

# %%
#5-hidden layered MLP
mlp_builder(5)

# %% [markdown]
# ### Observation:
# * For all the 3 models, the gape between the error curve or accuracy curve seems to increase after 2 epochs indicating the model's overfitting behaviour.
# * From the accuracy curve it is observed that with increasing number of layers the models performance also increases slightly but with adding unnecessary hidden layers may cause gradients to explode or diminish.

# %% [markdown]
# ## [B] Varying Optimizers

# %%
#MLPs with SGD, RMSprop, Adagrad optimizer
var_optimizer()

# %% [markdown]
# ### Observation:
# * From the error curve it is observed that the error rate decreases slowly with number of epochs for SGD classifier.
# * For RMSprop error starts from a low error rate and merges with minimal error rate very quickly than that of SGD.
# * Adagrad performed the best among all the optimization method as it merges to the global minimal very very quickly with in a couple of epochs.

# %% [markdown]
# ## [C] Varying Hidden Units

# %%
#MLP with varying hidden units
var_hidden_units()

# %% [markdown]
# ### Observation:
# * Above error curve shows with increasing number of hidden unites the model merges to the minimal error very quickly and model performance also increases.

# %% [markdown]
# ## [D] Varying Regularizers

# %%
#MLPs with L1, L2, L1-L2 and Dropout regularizers
var_regularizers()

# %% [markdown]
# ### Observation:
# * Both L1 and L1-L2 performed very similar and Dropout performed reasonably well but L2 performed best among all.

# %% [markdown]
# ## [E] Final MLP

# %%
#final model(without batch normalization)
final_mlp()
# Out:
# 10000/10000 [==============================] - 0s 44us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_46 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_47 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 10)                650
# ...
# Total params: 407,114
# Trainable params: 407,114
# Non-trainable params: 0
# ...

# %%
#final model(with batch normalization)
final_mlp()
# Out:
# 10000/10000 [==============================] - 0s 43us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_51 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_52 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_53 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# ...

# %% [markdown]
# ## 6.Summary:
# * Using all the best parameters from the previous experiments I modeled the final MLP with 5 hidden layers, reasonable hidden units and taking both L2 regularizers and Dropout with Adam optimizer and the test accuracy I got is 96.6%.
# * The same final model with batch normalization in its deep layer further pushed the performance to 97% accuracy.
